# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# --------------------------IRIS FLOWERS DATASET-------------------------------

# %%
iris_data = pd.read_csv('iris.csv')

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris_data.groupby('species').agg(['mean','max','min'])
# Out:
#            sepal_length           sepal_width           petal_length       \
#                    mean  max  min        mean  max  min         mean  max
# species
# setosa            5.006  5.8  4.3       3.428  4.4  2.3        1.462  1.9
# versicolor        5.936  7.0  4.9       2.770  3.4  2.0        4.260  5.1
# virginica         6.588  7.9  4.9       2.974  3.8  2.2        5.552  6.9
#
#                 petal_width
#             min        mean  max  min
# species
# setosa      1.0       0.246  0.6  0.1
# versicolor  3.0       1.326  1.8  1.0
# virginica   4.5       2.026  2.5  1.4

# %%
iris_data.sort_values(by='species', ascending=False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 149           5.9          3.0           5.1          1.8  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 120           6.9          3.2           5.7          2.3  virginica
# ..            ...          ...           ...          ...        ...
# 31            5.4          3.4           1.5          0.4     setosa
# 30            4.8          3.1           1.6          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 0             5.1          3.5           1.4          0.2     setosa
#
# [150 rows x 5 columns]

# %%
iris_data[iris_data['petal_length'] == iris_data['petal_length'].max()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 118           7.7          2.6           6.9          2.3  virginica

# %%
iris_data[iris_data['petal_length'] == iris_data['petal_length'].min()]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 22           4.6          3.6           1.0          0.2  setosa

# %%
sns.countplot(x='species', data=iris_data, hue='sepal_length')
plt.title('Species Distribution by Sepal Length')
# Out:
# Text(0.5, 1.0, 'Species Distribution by Sepal Length')

# %%
corr_iris = iris_data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].corr()
sns.heatmap(corr_iris, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# --------------------------------ABALONE DATASET----------------------------------

# %%
abalone_data = pd.read_csv('abalone.csv')

# %%
abalone_data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
abalone_data.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
abalone_data.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
abalone_data.groupby('Sex').agg(['mean', 'min', 'max'])
# Out:
#        Length                Diameter                 Height                \
#          mean    min    max      mean    min   max      mean    min    max
# Sex
# F    0.579093  0.275  0.815  0.454732  0.195  0.65  0.158011  0.015  1.130
# I    0.427746  0.075  0.725  0.326494  0.055  0.55  0.107996  0.000  0.220
# M    0.561391  0.155  0.780  0.439287  0.110  0.63  0.151381  0.025  0.515
#
#     Whole weight  ... Shucked weight Viscera weight                  \
#             mean  ...            max           mean     min     max
# Sex               ...
# F       1.046532  ...         1.4880       0.230689  0.0210  0.5900
# I       0.431363  ...         0.7735       0.092010  0.0005  0.4405
# M       0.991459  ...         1.3510       0.215545  0.0030  0.7600
#
#     Shell weight                     Rings
#             mean     min    max       mean min max
# Sex
# F       0.302010  0.0250  1.005  11.129304   5  29
# I       0.128182  0.0015  0.655   7.890462   1  21
# ...

# %%
abalone_data.sort_values(by='Sex', ascending=True)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 2088   F   0.720     0.575   0.215        2.1000          0.8565
# 1748   F   0.705     0.545   0.170        1.5800          0.6435
# 1747   F   0.700     0.535   0.175        1.7730          0.6805
# 1745   F   0.690     0.550   0.200        1.5690          0.6870
# 1744   F   0.685     0.565   0.175        1.6380          0.7775
# ...   ..     ...       ...     ...           ...             ...
# 2032   M   0.605     0.445   0.140        0.9820          0.4295
# 2033   M   0.610     0.490   0.160        1.1120          0.4650
# 2035   M   0.660     0.515   0.195        1.5655          0.7345
# 2024   M   0.545     0.440   0.140        0.8395          0.3560
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 2088          0.4825        0.6020     12
# 1748          0.4565        0.2650     11
# 1747          0.4800        0.5120     15
# ...

# %%
abalone_data[abalone_data['Height'] == abalone_data['Height'].max()]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 2051   F   0.455     0.355    1.13         0.594           0.332
#
#       Viscera weight  Shell weight  Rings
# 2051           0.116        0.1335      8

# %%
abalone_data[abalone_data['Height'] == abalone_data['Height'].min()]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 1257   I   0.430      0.34     0.0         0.428          0.2065
# 3996   I   0.315      0.23     0.0         0.134          0.0575
#
#       Viscera weight  Shell weight  Rings
# 1257          0.0860        0.1150      8
# 3996          0.0285        0.3505      6

# %%
sns.countplot(x='Sex', data=abalone_data, hue='Height')
plt.title('Sex Distribution by Height')
# Out:
# Text(0.5, 1.0, 'Sex Distribution by Height')

# %%
corr_abalone = abalone_data[['Length', 'Diameter','Height']].corr()
sns.heatmap(corr_abalone)
plt.title('Heatmap on Height, Diameter and Length')
# Out:
# Text(0.5, 1.0, 'Heatmap on Height, Diameter and Length')

# %% [markdown]
# -------------------------------------IONOSPHERE DATASET-----------------------------------

# %%
ionosphere_data = pd.read_csv('ionosphere.csv')

# %%
ionosphere_data.head()
# Out:
#    col_a  col_b    col_c    col_d    col_e    col_f    col_g    col_h  \
# 0      1      0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708
# 1      1      0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597
# 2      1      0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062
# 3      1      0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000
# 4      1      0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255
#
#      col_i    col_j  ...    col_z   col_aa   col_ab   col_ac   col_ad  \
# 0  1.00000  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090
# 1  1.00000 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593
# 2  0.88965  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365
# 3  0.00000  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099
# 4  0.77152 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197
#
#     col_ae   col_af   col_ag   col_ah  col_ai
# 0  0.42267 -0.54487  0.18641 -0.45300       g
# ...

# %%
ionosphere_data.describe()
# Out:
#             col_a  col_b       col_c       col_d       col_e       col_f  \
# count  351.000000  351.0  351.000000  351.000000  351.000000  351.000000
# mean     0.891738    0.0    0.641342    0.044372    0.601068    0.115889
# std      0.311155    0.0    0.497708    0.441435    0.519862    0.460810
# min      0.000000    0.0   -1.000000   -1.000000   -1.000000   -1.000000
# 25%      1.000000    0.0    0.472135   -0.064735    0.412660   -0.024795
# 50%      1.000000    0.0    0.871110    0.016310    0.809200    0.022800
# 75%      1.000000    0.0    1.000000    0.194185    1.000000    0.334655
# max      1.000000    0.0    1.000000    1.000000    1.000000    1.000000
#
#             col_g       col_h       col_i       col_j  ...       col_y  \
# count  351.000000  351.000000  351.000000  351.000000  ...  351.000000
# mean     0.550095    0.119360    0.511848    0.181345  ...    0.396135
# std      0.492654    0.520750    0.507066    0.483851  ...    0.578451
# ...

# %%
ionosphere_data.isnull().sum()
# Out:
# col_a     0
# col_b     0
# col_c     0
# col_d     0
# col_e     0
# col_f     0
# col_g     0
# col_h     0
# col_i     0
# col_j     0
# col_k     0
# col_l     0
# col_m     0
# col_n     0
# col_o     0
# col_p     0
# col_q     0
# col_r     0
# col_s     0
# col_t     0
# col_u     0
# col_v     0
# col_w     0
# col_x     0
# col_y     0
# col_z     0
# col_aa    0
# col_ab    0
# col_ac    0
# col_ad    0
# col_ae    0
# col_af    0
# col_ag    0
# col_ah    0
# col_ai    0
# dtype: int64

# %%
ionosphere_data['col_c'].value_counts()
# Out:
# col_c
#  1.00000    95
#  0.00000    25
# -1.00000    15
#  0.99539     1
#  0.60678     1
#             ..
#  0.25000     1
# -0.65625     1
#  0.85271     1
#  0.90374     1
#  0.84710     1
# Name: count, Length: 219, dtype: int64

# %%
sns.countplot(x='col_a', data=ionosphere_data, hue='col_g')
# Out:
# <Axes: xlabel='col_a', ylabel='count'>

# %%
ionosphere_data.sort_values(by='col_e', ascending=True)
# Out:
#      col_a  col_b    col_c    col_d  col_e    col_f    col_g    col_h  \
# 188      0      0 -1.00000  1.00000   -1.0 -1.00000  0.00000  0.00000
# 59       1      0  0.17188 -1.00000   -1.0  1.00000  0.00000  0.00000
# 232      0      0  1.00000  1.00000   -1.0 -1.00000 -1.00000 -1.00000
# 55       1      0  0.08333 -0.20685   -1.0  1.00000 -1.00000  1.00000
# 53       1      0 -0.67935 -1.00000   -1.0  1.00000  1.00000  0.63317
# ..     ...    ...      ...      ...    ...      ...      ...      ...
# 244      1      0  0.00000  0.00000    1.0  0.12889  0.88444 -0.02000
# 116      1      0  1.00000 -0.14754    1.0  0.04918  0.57377 -0.01639
# 119      1      0  0.86889 -0.07111    1.0 -0.02494  1.00000 -0.06889
# 235      1      0  0.76296 -0.07778    1.0 -0.29630  1.00000 -0.85741
# 175      1      0  1.00000  0.11765    1.0  0.23529  1.00000  0.41176
#
#        col_i    col_j  ...    col_z   col_aa   col_ab   col_ac   col_ad  \
# ...

# %% [markdown]
# --------------------------------------WHEAT SEEDS DATASET---------------------------------------

# %%
seeds_data = pd.read_csv('wheat seeds.csv')

# %%
seeds_data.head()
# Out:
#     Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0  15.26      14.84       0.8710          5.763         3.312
# 1  14.88      14.57       0.8811          5.554         3.333
# 2  14.29      14.09       0.9050          5.291         3.337
# 3  13.84      13.94       0.8955          5.324         3.379
# 4  16.14      14.99       0.9034          5.658         3.562
#
#    Asymmetry.Coeff  Kernel.Groove  Type
# 0            2.221          5.220     1
# 1            1.018          4.956     1
# 2            2.699          4.825     1
# 3            2.259          4.805     1
# 4            1.355          5.175     1

# %%
seeds_data.describe()
# Out:
#              Area   Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# count  199.000000  199.000000   199.000000     199.000000    199.000000
# mean    14.918744   14.595829     0.870811       5.643151      3.265533
# std      2.919976    1.310445     0.023320       0.443593      0.378322
# min     10.590000   12.410000     0.808100       4.899000      2.630000
# 25%     12.330000   13.470000     0.857100       5.267000      2.954500
# 50%     14.430000   14.370000     0.873400       5.541000      3.245000
# 75%     17.455000   15.805000     0.886800       6.002000      3.564500
# max     21.180000   17.250000     0.918300       6.675000      4.033000
#
#        Asymmetry.Coeff  Kernel.Groove        Type
# count       199.000000     199.000000  199.000000
# mean          3.699217       5.420653    1.994975
# std           1.471102       0.492718    0.813382
# min           0.765100       4.519000    1.000000
# 25%           2.570000       5.046000    1.000000
# ...

# %%
seeds_data.isnull().sum()
# Out:
# Area               0
# Perimeter          0
# Compactness        0
# Kernel.Length      0
# Kernel.Width       0
# Asymmetry.Coeff    0
# Kernel.Groove      0
# Type               0
# dtype: int64

# %%
seeds_data[seeds_data['Kernel.Length'] == seeds_data['Kernel.Length'].max()]
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 103  19.94      16.92       0.8752          6.675         3.763
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 103            3.252           6.55     2

# %%
seeds_data[seeds_data['Kernel.Length'] == seeds_data['Kernel.Length'].min()]
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 180  10.59      12.41       0.8648          4.899         2.787
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 180            4.975          4.794     3

# %%
seeds_data.sort_values(by='Area', ascending=False).head(30)
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 84   21.18      17.21       0.8989          6.573         4.033
# 109  20.97      17.25       0.8859          6.563         3.991
# 85   20.88      17.05       0.9031          6.450         4.032
# 73   20.71      17.23       0.8763          6.579         3.814
# 115  20.24      16.91       0.8897          6.315         3.962
# 78   20.20      16.89       0.8894          6.285         3.864
# 123  20.16      17.03       0.8735          6.513         3.773
# 86   20.10      16.99       0.8746          6.581         3.785
# 114  20.03      16.90       0.8811          6.493         3.857
# 103  19.94      16.92       0.8752          6.675         3.763
# 79   19.57      16.74       0.8779          6.384         3.772
# 80   19.51      16.71       0.8780          6.366         3.801
# 98   19.46      16.50       0.8985          6.113         3.892
# 106  19.38      16.72       0.8716          6.303         3.791
# ...

# %%
corr_seeds = seeds_data[['Area','Perimeter','Kernel.Length','Kernel.Width']].corr()
sns.heatmap(corr_seeds)
plt.title("HeatMap of Correlation about the Seeds")
# Out:
# Text(0.5, 1.0, 'HeatMap of Correlation about the Seeds')

# %% [markdown]
# ---------------------------------------BOSTON HOUSING PRICE-------------------------------------------

# %%
house_data = pd.read_csv('bostonhousing.csv')

# %%
house_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B    LSTAT  MEDV
# 0     15.3  396.90     4.98  24.0
# 1     17.8  396.90     9.14  21.6
# 2     17.8  392.83     4.03  34.7
# 3     18.7  394.63     2.94  33.4
# 4     18.7  396.90     5.33  36.2

# %%
house_data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
house_data.isnull().sum()
# Out:
# CRIM        0
# ZN          0
# INDUS       0
# CHAS        0
# NOX         0
# RM          0
# AGE         0
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT       0
# MEDV       28
# dtype: int64

# %%
house_data[house_data['CRIM'] == house_data['CRIM'].max()]
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 380  88.9762  0.0   18.1     0  0.671  6.968  91.9  1.4165   24  666.0
#
#      PTRATIO      B    LSTAT  MEDV
# 380     20.2  396.9    17.21  10.4

# %%
house_data[house_data['CRIM'] == house_data['CRIM'].min()]
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE   DIS  RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.09    1  296.0     15.3
#
#        B    LSTAT  MEDV
# 0  396.9     4.98  24.0

# %%
house_data.sort_values(by='CRIM', ascending=False).head(40)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 380  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666.0
# 418  73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24  666.0
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666.0
# 410  51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24  666.0
# 414  45.7461  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666.0
# 404  41.5292  0.0   18.1     0  0.693  5.531   85.4  1.6074   24  666.0
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666.0
# 427  37.6619  0.0   18.1     0  0.679  6.202   78.7  1.8629   24  666.0
# 413  28.6558  0.0   18.1     0  0.597  5.155  100.0  1.5894   24  666.0
# 417  25.9406  0.0   18.1     0  0.679  5.304   89.1  1.6475   24  666.0
# 400  25.0461  0.0   18.1     0  0.693  5.987  100.0  1.5888   24  666.0
# 403  24.8017  0.0   18.1     0  0.693  5.349   96.0  1.7028   24  666.0
# ...

# %%
sns.countplot(x='CRIM', data=house_data)
plt.title('Distribution of CRIM')
# Out:
# Text(0.5, 1.0, 'Distribution of CRIM')

# %%
corr_house = house_data[['CRIM','ZN','TAX']].corr()
sns.heatmap(corr_house)
plt.title('HeatMap for Correlation of Boston Houses')
# Out:
# Text(0.5, 1.0, 'HeatMap for Correlation of Boston Houses')
